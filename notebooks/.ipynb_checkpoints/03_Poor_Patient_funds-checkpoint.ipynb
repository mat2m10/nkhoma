# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
pd.set_option("future.no_silent_downcasting", True)
 
from laparoscopy_helpers.data_cleaning import to_snake_case, clean_surgical_df
from poor_patient_helpers.data_cleaning import load_all_endo

# %%
cleaned_theatre_book = pd.read_excel(
    "../Nkhoma_data/theatre_book_data/combined_clean.xlsx",
    engine="openpyxl"
)

# %%
endo_path = "../Nkhoma_data/poor_patients_funds_data/Endoscopy Ledger"
combined = load_all_endo(endo_path, verbose=True)
# Out:
# ✓ 22 May               → 14 rows
# ✓ 22 June              → 7 rows
# ✓ 22 Aug               → 14 rows
# ✓ 22 Sept              → 6 rows
# ✓ 22 Oct               → 5 rows
# ✓ 22 Nov               → 7 rows
# ✓ 22 Dec               → 6 rows
# ✓ 23 JAN               → 9 rows
# ✓ 23 FEB               → 11 rows
# ✓ 23 MAR               → 9 rows
# ✓ 23 APR               → 16 rows
# ✓ 23 MAY               → 6 rows
# ✓ 23 SEPT              → 21 rows
# ✓ 23 OCT               → 4 rows
# ✓ 23 NOV               → 14 rows
# ✓ 23 DEC               → 9 rows
# ✓ 2024 FULL LIST       → 124 rows
# ✓ January              → 15 rows
# ✓ February             → 15 rows
# ✓ March                → 20 rows
# ✓ April                → 20 rows
# ✓ May                  → 20 rows
# ✓ June                 → 25 rows
# ✓ July                 → 20 rows
# ✓ August               → 28 rows
# ✓ September            → 27 rows
# ✓ October              → 27 rows
# ✓ November             → 27 rows
# ...

# %%
print(combined.shape)
print(combined.isnull().mean().round(2).sort_values(ascending=False))
print(combined["admission_date"].min(), "→", combined["admission_date"].max())
combined.tail()
# Out:
# (468, 14)
# diagnosis                      0.31
# id                             0.29
# patient_number                 0.29
# gender                         0.29
# surgery                        0.29
# invoice_number                 0.29
# discharge_date                 0.02
# copay_mk                       0.01
# name                           0.00
# admission_date                 0.00
# total_bill_mk                  0.00
# endoscopy_ledger_balance_mk    0.00
# source_file                    0.00
# source_sheet                   0.00
# dtype: float64
# 2022-04-07 00:00:00 → 2025-12-28 00:00:00
#     id patient_number                   name  gender             diagnosis  \
# 463  3          20393       Frank Mtambalika    Male                  LGIB
# 464  4          30792  Elidio Adraia Gabouza    Male  Esophageal Stricture
# 465  5          13286       Catherine Samuel  Female  Duodenal Ulcer; UGIB
# 466  6          33273         Ibula Maluwile    Male             Dysphagia
# ...
