# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
pd.set_option("future.no_silent_downcasting", True)
 
from laparoscopy_helpers.data_cleaning import to_snake_case, clean_surgical_df
from poor_patient_helpers.data_cleaning import load_all_endo, load_all_mercy, load_all_safe, build_final

# %%
TB = pd.read_excel(
    "../Nkhoma_data/theatre_book_data/combined_clean.xlsx",
    engine="openpyxl"
)

# %%
base_path = "../Nkhoma_data/poor_patients_funds_data"

endo  = load_all_endo(f"{base_path}/Endoscopy Ledger")
mercy = load_all_mercy(f"{base_path}/Mercy Fund")
safe  = load_all_safe(f"{base_path}/SAFE")
# Out:
# ✓ endo  22 May               → 14 rows
# ✓ endo  22 June              → 7 rows
# ✓ endo  22 Aug               → 14 rows
# ✓ endo  22 Sept              → 6 rows
# ✓ endo  22 Oct               → 5 rows
# ✓ endo  22 Nov               → 7 rows
# ✓ endo  22 Dec               → 6 rows
# ✓ endo  23 JAN               → 9 rows
# ✓ endo  23 FEB               → 11 rows
# ✓ endo  23 MAR               → 9 rows
# ✓ endo  23 APR               → 16 rows
# ✓ endo  23 MAY               → 6 rows
# ✓ endo  23 SEPT              → 21 rows
# ✓ endo  23 OCT               → 4 rows
# ✓ endo  23 NOV               → 14 rows
# ✓ endo  23 DEC               → 9 rows
# ✓ endo  2024 FULL LIST       → 124 rows
# ✓ endo  January              → 15 rows
# ✓ endo  February             → 15 rows
# ✓ endo  March                → 20 rows
# ✓ endo  April                → 20 rows
# ✓ endo  May                  → 20 rows
# ✓ endo  June                 → 25 rows
# ✓ endo  July                 → 20 rows
# ✓ endo  August               → 28 rows
# ✓ endo  September            → 27 rows
# ✓ endo  October              → 27 rows
# ✓ endo  November             → 27 rows
# ✓ endo  December             → 27 rows
# ✓ mercy All                  (SURGICAL MERCY FUND ALL until ) → 339 rows
# ✓ mercy CONSOLIDATED         (Mercy Fund Report- Jan-Dec 202) → 500 rows
# ✓ mercy JANUARY              (Mercy Fund Report- Jan-Dec 202) → 28 rows
# ✓ mercy FEBRUARY             (Mercy Fund Report- Jan-Dec 202) → 44 rows
# ✓ mercy MARCH                (Mercy Fund Report- Jan-Dec 202) → 61 rows
# ✓ mercy APRIL                (Mercy Fund Report- Jan-Dec 202) → 62 rows
# ✓ mercy MAY                  (Mercy Fund Report- Jan-Dec 202) → 62 rows
# ✓ mercy JUNE                 (Mercy Fund Report- Jan-Dec 202) → 54 rows
# ✓ mercy JULY                 (Mercy Fund Report- Jan-Dec 202) → 58 rows
# ✓ mercy AUGUST               (Mercy Fund Report- Jan-Dec 202) → 39 rows
# ✓ mercy SEPTEMBER            (Mercy Fund Report- Jan-Dec 202) → 57 rows
# ✓ mercy OCTOBER              (Mercy Fund Report- Jan-Dec 202) → 60 rows
# ✓ mercy NOVEMBER             (Mercy Fund Report- Jan-Dec 202) → 36 rows
# ✓ mercy DECEMBER             (Mercy Fund Report- Jan-Dec 202) → 24 rows
#   → possible mercy duplicates flagged: 16
# ✓ safe  SAFE Program 2022.xlsx                                  → 79 rows
# ✓ safe  SAFE 2023 REPORT.xlsx                                   → 185 rows
# ✓ safe  Master SAFE Patient Spreadsheet 2024_Nkhoma Hospital.xl → 181 rows
# ✓ safe  Master SAFE Patient Spreadsheet 2025_Nkhoma Hospital FI → 125 rows
#   → possible safe duplicates flagged: 1

# %%
endo
# Out:
#       id patient_number           patient_name              full_name  \
# 0    NaN            NaN      Pitilizani Gidala      PITILIZANI GIDALA
# 1    NaN            NaN          Ellena Mulazi          ELLENA MULAZI
# 2    NaN            NaN      Christina Manyowa      CHRISTINA MANYOWA
# 3    NaN            NaN         Alice Jeremani         ALICE JEREMANI
# 4    NaN            NaN       Catherine Samuel       CATHERINE SAMUEL
# ..   ...            ...                    ...                    ...
# 463    3          20393       Frank Mtambalika       FRANK MTAMBALIKA
# 464    4          30792  Elidio Adraia Gabouza  ELIDIO ADRAIA GABOUZA
# 465    5          13286       Catherine Samuel       CATHERINE SAMUEL
# 466    6          33273         Ibula Maluwile         IBULA MALUWILE
# 467    7          32559         Fredson Kameta         FREDSON KAMETA
#
#                       name  gender             diagnosis        surgery  \
# 0        Pitilizani Gidala     NaN                   NaN            NaN
# 1            Ellena Mulazi     NaN                   NaN            NaN
# 2        Christina Manyowa     NaN                   NaN            NaN
# 3           Alice Jeremani     NaN                   NaN            NaN
# 4         Catherine Samuel     NaN                   NaN            NaN
# ..                     ...     ...                   ...            ...
# 463       Frank Mtambalika    Male                  LGIB    Colonoscopy
# 464  Elidio Adraia Gabouza    Male  Esophageal Stricture            EGD
# 465       Catherine Samuel  Female  Duodenal Ulcer; UGIB            EGD
# 466         Ibula Maluwile    Male             Dysphagia   EGD + Biopsy
# 467         Fredson Kameta    Male          UGI Bleeding  EGD + Banding
#
#     admission_date discharge_date total_bill_mk copay_mk  \
# 0       2022-05-11     2022-05-11         85250    22000
# 1       2022-05-11     2022-05-12         83970        0
# 2       2022-05-11     2022-05-13         99770    65000
# 3       2022-05-18     2022-05-18         75820        0
# 4       2022-05-18     2022-05-19        100570    20570
# ..             ...            ...           ...      ...
# 463     2025-12-17     2025-12-19        381400   100000
# 464     2025-12-08     2025-12-11        704950   100000
# 465     2025-12-28     2025-12-29        229200    50000
# 466     2025-12-11     2025-12-12        266000    80000
# 467     2025-12-06     2025-12-10        479800   100000
#
#     endoscopy_ledger_balance_mk invoice_number  \
# 0                         63250            NaN
# 1                         83970            NaN
# 2                         34770            NaN
# 3                         75820            NaN
# 4                         80000            NaN
# ..                          ...            ...
# 463                      281400          91346
# 464                      200000          89563
# 465                      179200          92640
# 466                      186000          89806
# 467                      379800          89433
#
#                                source_file source_sheet
# 0         Endoscopy Ledger_ 2022-2023.xlsx       22 May
# 1         Endoscopy Ledger_ 2022-2023.xlsx       22 May
# 2         Endoscopy Ledger_ 2022-2023.xlsx       22 May
# 3         Endoscopy Ledger_ 2022-2023.xlsx       22 May
# 4         Endoscopy Ledger_ 2022-2023.xlsx       22 May
# ..                                     ...          ...
# 463  Endoscopy Ledger_2025 02.04.2026.xlsx     December
# 464  Endoscopy Ledger_2025 02.04.2026.xlsx     December
# 465  Endoscopy Ledger_2025 02.04.2026.xlsx     December
# 466  Endoscopy Ledger_2025 02.04.2026.xlsx     December
# 467  Endoscopy Ledger_2025 02.04.2026.xlsx     December
#
# [468 rows x 16 columns]

# %%
final = build_final(TB, mercy, safe, endo, verbose=True)
# Out:
# =======================================================
# Final shape: (2543, 42)
#
# Match status:
# match_status  matched  unmatched
# fund
# endo              227        259
# mercy             746        717
# safe              391        203
#
# Matched dept distribution:
# department  Gen_Surg  Ortho
# fund
# endo             227      0
# mercy            703     43
# safe             263    128
#
# Cross-fund double-billing flags: 14
# /home/mat2m10/code/mat2m10/nkhoma/notebooks/poor_patient_helpers/data_cleaning.py:688: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   links = pd.concat([mercy_links, safe_links, endo_links], ignore_index=True)

# %%
matched = final[final["match_status"] == "matched"].copy()
unmatched = final[final["match_status"] == "unmatched"].copy()

# %%
matched
# Out:
#        fund match_status match_type  fuzzy_score unmatched_reason  \
# 127   mercy      matched      token        1.000             None
# 540   mercy      matched      exact        1.000             None
# 541   mercy      matched      fuzzy        0.917             None
# 545   mercy      matched      fuzzy        0.857             None
# 546   mercy      matched      fuzzy        0.897             None
# ...     ...          ...        ...          ...              ...
# 2328   endo      matched      exact        1.000             None
# 2329   endo      matched      fuzzy        0.923             None
# 2330   endo      matched      exact        1.000             None
# 2331   endo      matched      exact        1.000             None
# 2333   endo      matched      exact        1.000             None
#
#      cross_fund_flag           fund_name patient_number  age  gender  ...  \
# 127            False  PETER FOSTER DZUWA           9694  NaN    Male  ...
# 540            False        MARTIN JAMES          35558  NaN    Male  ...
# 541            False        EDWIN WALUZA          36838  NaN    Male  ...
# 545            False     BREFFINE MTONGA          76919  NaN    Male  ...
# 546            False     BREFFINE MTONGA          76919  NaN    Male  ...
# ...              ...                 ...            ...  ...     ...  ...
# 2328           False     TIMOTHY ABRAHAM         319650  NaN    Male  ...
# 2329           False       MARRIAM ONANI         397296  NaN  Female  ...
# 2330           False        ELIZA MTAULA         397083  NaN  Female  ...
# 2331           False       PATRICK BANDA         396613  NaN    Male  ...
# 2333           False      CHRISSY NKHOKO         391265  NaN  Female  ...
#
#                               procedure_free_text    tb_surgery_type  \
# 127                                           NaN  Any Other Surgery
# 540                                           NaN                NaN
# 541                                          TURP  Any Other Surgery
# 545                                           NaN            Urology
# 546                                           NaN            Urology
# ...                                           ...                ...
# 2328  EGD + Banding / Grade IV Esophageal Varices                NaN
# 2329             EGD + Biopsy / Retrosternal Pain                NaN
# 2330                     EGD + biopsy / dyspepsia                NaN
# 2331                                         EGD                 NaN
# 2333              EGD + Biopsy / Esophageal Tumor                NaN
#
#         indication_for_surgery   urgency surgery_severity asascore  \
# 127   Non-Communicable Disease  Elective     Intermediate      NaN
# 540                  Infection    Urgent            Minor      NaN
# 541   Non-Communicable Disease       NaN              NaN      NaN
# 545   Non-Communicable Disease  Elective            Major    ASA 2
# 546   Non-Communicable Disease  Elective            Major    ASA 2
# ...                        ...       ...              ...      ...
# 2328  Non-Communicable Disease       NaN              NaN    ASA 2
# 2329  Non-Communicable Disease       NaN              NaN      NaN
# 2330  Non-Communicable Disease       NaN              NaN    ASA 1
# 2331  Non-Communicable Disease       NaN              NaN    ASA 1
# 2333  Non-Communicable Disease       NaN              NaN    ASA 3
#
#       days_since_last_mercy  possible_duplicate_mercy  days_since_last_safe  \
# 127                     NaN                     False                   NaN
# 540                     NaN                     False                   NaN
# 541                     NaN                     False                   NaN
# 545                     NaN                     False                   NaN
# 546                     NaN                     False                   NaN
# ...                     ...                       ...                   ...
# 2328                    NaN                       NaN                   NaN
# 2329                    NaN                       NaN                   NaN
# 2330                    NaN                       NaN                   NaN
# 2331                    NaN                       NaN                   NaN
# 2333                    NaN                       NaN                   NaN
#
#       possible_duplicate_safe
# 127                       NaN
# 540                       NaN
# 541                       NaN
# 545                       NaN
# 546                       NaN
# ...                       ...
# 2328                      NaN
# 2329                      NaN
# 2330                      NaN
# 2331                      NaN
# 2333                      NaN
#
# [1364 rows x 42 columns]

# %%
unmatched
# Out:
#        fund match_status match_type  fuzzy_score  unmatched_reason  \
# 0     mercy    unmatched  unmatched          NaN  outside_TB_range
# 1     mercy    unmatched  unmatched          NaN  outside_TB_range
# 2     mercy    unmatched  unmatched          NaN  outside_TB_range
# 3     mercy    unmatched  unmatched          NaN  outside_TB_range
# 4     mercy    unmatched  unmatched          NaN  outside_TB_range
# ...     ...          ...        ...          ...               ...
# 2538   endo    unmatched  unmatched          NaN  outside_TB_range
# 2539   endo    unmatched  unmatched          NaN  outside_TB_range
# 2540   endo    unmatched  unmatched          NaN  outside_TB_range
# 2541   endo    unmatched  unmatched          NaN  outside_TB_range
# 2542   endo    unmatched  unmatched          NaN  outside_TB_range
#
#      cross_fund_flag              fund_name patient_number  age  gender  ...  \
# 0              False         MOSES MANGUISA             66  NaN    Male  ...
# 1              False       KACHIGAMBA MWALE            276  NaN    Male  ...
# 2              False        EFRINA CHIKONDI            362  NaN  Female  ...
# 3              False          PAMELA MWELWA            706  NaN  Female  ...
# 4              False           ERIC MALINGA            922  NaN    Male  ...
# ...              ...                    ...            ...  ...     ...  ...
# 2538           False       FRANK MTAMBALIKA          20393  NaN    Male  ...
# 2539           False  ELIDIO ADRAIA GABOUZA          30792  NaN    Male  ...
# 2540           False       CATHERINE SAMUEL          13286  NaN  Female  ...
# 2541           False         IBULA MALUWILE          33273  NaN    Male  ...
# 2542           False         FREDSON KAMETA          32559  NaN    Male  ...
#
#      procedure_free_text tb_surgery_type indication_for_surgery  urgency  \
# 0                    NaN             NaN                    NaN     None
# 1                    NaN             NaN                    NaN     None
# 2                    NaN             NaN                    NaN     None
# 3                    NaN             NaN                    NaN     None
# 4                    NaN             NaN                    NaN     None
# ...                  ...             ...                    ...      ...
# 2538                 NaN             NaN                    NaN     None
# 2539                 NaN             NaN                    NaN     None
# 2540                 NaN             NaN                    NaN     None
# 2541                 NaN             NaN                    NaN     None
# 2542                 NaN             NaN                    NaN     None
#
#      surgery_severity asascore  days_since_last_mercy  \
# 0                None      NaN                    NaN
# 1                None      NaN                    NaN
# 2                None      NaN                    NaN
# 3                None      NaN                    NaN
# 4                None      NaN                    NaN
# ...               ...      ...                    ...
# 2538             None      NaN                    NaN
# 2539             None      NaN                    NaN
# 2540             None      NaN                    NaN
# 2541             None      NaN                    NaN
# 2542             None      NaN                    NaN
#
#       possible_duplicate_mercy  days_since_last_safe  possible_duplicate_safe
# 0                        False                   NaN                      NaN
# 1                        False                   NaN                      NaN
# 2                        False                   NaN                      NaN
# 3                        False                   NaN                      NaN
# 4                        False                   NaN                      NaN
# ...                        ...                   ...                      ...
# 2538                       NaN                   NaN                      NaN
# 2539                       NaN                   NaN                      NaN
# 2540                       NaN                   NaN                      NaN
# 2541                       NaN                   NaN                      NaN
# 2542                       NaN                   NaN                      NaN
#
# [1179 rows x 42 columns]

# %%
not_in_TB = unmatched[unmatched['unmatched_reason'] != "outside_TB_range"]

# %%
# ── 1. Confirm Ortho + Gen_Surg only for SAFE and Mercy ──────────────
print("=== Q1: Department distribution (matched only) ===")
print(matched.groupby(["fund", "department"]).size().unstack(fill_value=0))

# ── 2. Cross-fund double-billing check ───────────────────────────────
# Same patient_number appearing in both mercy and safe
mercy_ids = set(final[final["fund"]=="mercy"]["patient_number"].dropna().astype(str))
safe_ids  = set(final[final["fund"]=="safe"]["patient_number"].dropna().astype(str))
endo_ids  = set(endo["patient_number"].dropna().astype(str))

print(f"\n=== Q2: Cross-fund overlap (should be ~0) ===")
print(f"Mercy ∩ Safe:  {len(mercy_ids & safe_ids)}")
print(f"Mercy ∩ Endo:  {len(mercy_ids & endo_ids)}")
print(f"Safe  ∩ Endo:  {len(safe_ids  & endo_ids)}")

if mercy_ids & safe_ids:
    overlap = sorted(mercy_ids & safe_ids)
    print(f"Overlapping IDs: {overlap[:10]}")

# ── 3. One admission → many procedures ───────────────────────────────
print("\n=== Q3: Procedures per fund entry (1 fund row → N theatre rows) ===")
multi = (matched.groupby(["fund", "fund_name", "fund_admission_date"])
         ["theatre_index"].count()
         .reset_index(name="n_procedures"))
print(multi["n_procedures"].value_counts().sort_index())
print("\nSample multi-procedure cases:")
print(multi[multi["n_procedures"] > 1]
      .sort_values("n_procedures", ascending=False)
      .head(10).to_string())

# ── 4. Coverage summary: how many TB procedures were covered ──────────
print("\n=== Q4: Theatre book coverage ===")
tb_total = len(TB[TB["department"].isin(["Gen_Surg", "Ortho"])])
tb_covered = matched["theatre_index"].nunique()
print(f"TB Gen_Surg + Ortho procedures total:   {tb_total}")
print(f"Covered by a fund (unique TB entries):  {tb_covered}")
print(f"Coverage rate:                          {tb_covered/tb_total:.1%}")

print("\nCovered by fund:")
print(matched.groupby("fund")["theatre_index"].nunique())

# ── 5. Procedure breakdown for covered cases ─────────────────────────
print("\n=== Q5: What procedures were covered? (tb_diagnosis) ===")
proc_table = (matched.groupby(["fund", "tb_diagnosis"])
              .size()
              .reset_index(name="n")
              .pivot_table(index="tb_diagnosis", columns="fund", 
                           values="n", fill_value=0)
              .sort_values("mercy", ascending=False))
print(proc_table.head(20).to_string())

# ── 6. Unmatched breakdown ────────────────────────────────────────────
print("\n=== Q6: Unmatched fund entries ===")
print(unmatched.groupby(["fund", "unmatched_reason"]).size().unstack(fill_value=0))

unmatched_in_range = unmatched[unmatched["unmatched_reason"] == "not_in_TB"]
print(f"\nUnmatched within TB date range: {len(unmatched_in_range)}")
print("These are likely endoscopy-only or missing TB entries")

# ── 7. Financial summary ──────────────────────────────────────────────
print("\n=== Q7: Financial summary (matched cases only) ===")
fin = (matched.drop_duplicates(subset=["fund", "fund_name", "fund_admission_date"])
       .groupby("fund")
       .agg(
           n_cases       =("fund_name",       "count"),
           total_billed  =("total_bill_mk",   "sum"),
           total_copay   =("copay_mk",        "sum"),
           total_covered =("fund_covered_mk", "sum"),
       ))
fin["avg_covered_per_case"] = (fin["total_covered"] / fin["n_cases"]).round(0)
print(fin.to_string())
# Out:
# === Q1: Department distribution (matched only) ===
# department  Gen_Surg  Ortho
# fund
# mercy            703     43
# safe             263    128
#
# === Q2: Cross-fund overlap (should be ~0) ===
# Mercy ∩ Safe:  15
# Mercy ∩ Endo:  7
# Safe  ∩ Endo:  3
# Overlapping IDs: ['133337', '15031', '19669', '20643', '372415', '373557', '383000', '383228', '384127', '389772']
#
# === Q3: Procedures per fund entry (1 fund row → N theatre rows) ===
# n_procedures
# 1    851
# 2     77
# 3     13
# 4      4
# Name: count, dtype: int64
#
# Sample multi-procedure cases:
#       fund          fund_name fund_admission_date  n_procedures
# 505  mercy     PEMPHERO MARKO          2024-03-15             4
# 496  mercy     OLASIO ANTONIO          2024-05-13             4
# 629  mercy    YESAYA LATUMELO          2023-08-14             4
# 495  mercy    OLASIO ANTHONYO          2024-04-05             4
# 9    mercy  ALBERT KANKHUMBWA          2023-08-23             3
# 256  mercy     GENESIS MALAKI          2024-01-27             3
# 346  mercy      KAMBANI ISAAC          2023-03-14             3
# 378  mercy       LELIA JAPION          2024-01-26             3
# 347  mercy      KAMBANI ISAAC          2023-03-29             3
# 480  mercy     MPAPA CHISAMBA          2024-02-27             3
#
# === Q4: Theatre book coverage ===
# TB Gen_Surg + Ortho procedures total:   3243
# Covered by a fund (unique TB entries):  1097
# Coverage rate:                          33.8%
#
# Covered by fund:
# fund
# mercy    722
# safe     389
# Name: theatre_index, dtype: int64
#
# === Q5: What procedures were covered? (tb_diagnosis) ===
# fund                     mercy  safe
# tb_diagnosis
# Other_Surg               309.0  64.0
# Bph                       71.0  63.0
# Inguinal_Hernia           53.0  64.0
# Bowel_Obstruction         27.0   4.0
# Other_Ortho               26.0  43.0
# Abscess_Infection         23.0   1.0
# Lipoma_Subcut_Tumor       15.0   3.0
# Appendicitis              14.0   1.0
# Ventral_Hernia            12.0  14.0
# Cancer                    11.0   5.0
# Volvulus                  11.0   1.0
# Dysphagia                 11.0   1.0
# Umbilical_Hernia          10.0   6.0
# Fracture                   8.0  66.0
# Perforation                8.0   1.0
# Gi_Bleeding                8.0   0.0
# Dyspepsia                  6.0   1.0
# Thyroid                    4.0   6.0
# Cholecystolitiasis_Itis    4.0   3.0
# Burns                      1.0   0.0
#
# === Q6: Unmatched fund entries ===
# unmatched_reason  not_in_TB  outside_TB_range
# fund
# mercy                   153               564
# safe                     49               124
#
# Unmatched within TB date range: 202
# These are likely endoscopy-only or missing TB entries
#
# === Q7: Financial summary (matched cases only) ===
#        n_cases  total_billed  total_copay  total_covered  avg_covered_per_case
# fund
# mercy      650   149570840.0   43039020.0    102717975.0              158028.0
# safe       359   127629506.0    4776000.0    -11175764.0              -31130.0

# %%
# ── Investigate cross-fund overlaps ───────────────────────────────────
overlap_ids = mercy_ids & safe_ids
overlap_cases = final[final["patient_number"].astype(str).isin(overlap_ids)][
    ["fund", "patient_number", "fund_name", "fund_admission_date",
     "total_bill_mk", "fund_covered_mk", "department"]
].sort_values(["patient_number", "fund_admission_date"])
print("=== Cross-fund patients (mercy AND safe) ===")
print(overlap_cases.to_string())

# ── Flag OLASIO duplicate ─────────────────────────────────────────────
print("\n=== OLASIO entries — likely same person? ===")
print(final[final["fund_name"].str.contains("OLASIO", na=False)][
    ["fund", "fund_name", "patient_number", "fund_admission_date",
     "theatre_index", "theatre_name", "tb_diagnosis"]
].to_string())

# ── SAFE financial note ───────────────────────────────────────────────
print("\n=== SAFE: safe_fund_mk distribution ===")
safe_fin = final[final["fund"] == "safe"].drop_duplicates(
    subset=["fund_name", "fund_admission_date"])
print(f"Positive (SAFE covered more than billed): "
      f"{(safe_fin['safe_fund_mk'] > 0).sum()}")
print(f"Negative (SAFE fixed price < actual bill): "
      f"{(safe_fin['safe_fund_mk'] < 0).sum()}")
print(f"Null: {safe_fin['safe_fund_mk'].isna().sum()}")
print(f"\nMedian safe_ask_usd: ${safe_fin['safe_ask_usd'].median():.0f}")
print(f"Median total_bill_mk: {safe_fin['total_bill_mk'].median():,.0f} MK")
# Out:
# === Cross-fund patients (mercy AND safe) ===
#        fund patient_number            fund_name fund_admission_date  total_bill_mk  fund_covered_mk department
# 72    mercy           5882          SONGO LINJE          2025-02-25       370000.0         320000.0       None
# 1482   safe           5882          SONGO LINJE          2025-05-29       882504.0         -38826.0       None
# 75    mercy           6086       ATANAZIO BANDA          2025-02-23       203400.0          63400.0       None
# 1483   safe           6086       ATANAZIO BANDA          2025-03-06       882504.0         142844.0       None
# 1488   safe           6960        ARMANDO KOREA          2025-03-13       882504.0         101944.0       None
# 91    mercy           6960       ALUMANDO KOREA          2025-05-06       175700.0         125700.0       None
# 1489   safe           7877  CHIMTHUNZI KUTCHIKA          2025-03-20       882504.0          73744.0       None
# 103   mercy           7877   CHINTHUZI KUTCHIKA          2025-03-28        95540.0          95540.0       None
# 1525   safe          15031        ALFRED YOHANE          2025-05-08       882504.0          -6856.0       None
# 218   mercy          15031        ALFRED YOHANE          2025-05-20       318050.0         248050.0       None
# 1546   safe          19669      TOBALA CHISAMBA          2025-04-09       490280.0        -629500.0       None
# 298   mercy          19669      TOBALA CHISAMBA          2025-06-04       339800.0         339800.0       None
# 1550   safe          20643      WILSON KANYEMBA          2025-07-27       882504.0        -590496.0       None
# 315   mercy          20643      WILSON KANYEMBA          2025-08-05       290800.0         275800.0       None
# 554   mercy         133337      PERISTER GETALA          2024-09-03       743550.0         693550.0   Gen_Surg
# 555   mercy         133337      PERISTER GETALA          2024-09-03       743550.0         693550.0   Gen_Surg
# 556   mercy         133337      PERISTER GETALA          2024-09-03       743550.0         693550.0   Gen_Surg
# 1579   safe         133337       PERISTA GETALA          2024-12-11      1147500.0         312770.0       None
# 994   mercy         372415          SIMAO BANDA          2024-02-24       207980.0         157980.0       None
# 1604   safe         372415        SMAOH BERNADO          2024-03-14       882504.0        -274276.0   Gen_Surg
# 1610   safe         373557       MPAPA CHISAMBA          2024-02-22       882504.0         -78156.0   Gen_Surg
# 1611   safe         373557       MPAPA CHISAMBA          2024-02-22       882504.0         -78156.0   Gen_Surg
# 1612   safe         373557       MPAPA CHISAMBA          2024-02-22       882504.0         -78156.0   Gen_Surg
# 1007  mercy         373557       MPAPA CHISAMBA          2024-02-27       454760.0         354760.0   Gen_Surg
# 1008  mercy         373557       MPAPA CHISAMBA          2024-02-27       454760.0         354760.0   Gen_Surg
# 1009  mercy         373557       MPAPA CHISAMBA          2024-02-27       454760.0         354760.0   Gen_Surg
# 1150  mercy         383000         FUNANI NKOKA          2024-06-19       240600.0         190600.0   Gen_Surg
# 1151  mercy         383000         FUNANI NJOKA          2024-07-24       485500.0         435500.0   Gen_Surg
# 1656   safe         383000         FUNANI NJOKA          2024-09-05       833476.0         267646.0   Gen_Surg
# 1658   safe         383228        DAVISON BANDA          2024-07-16       882504.0         -58056.0   Gen_Surg
# 1159  mercy         383228        DAVISON BANDA          2024-10-09       241450.0         191450.0   Gen_Surg
# 1172  mercy         384127       DIVASON MATEYU          2024-06-23       253450.0         193450.0   Gen_Surg
# 1173  mercy         384127       DIVASON MATEYU          2024-06-23       253450.0         193450.0   Gen_Surg
# 1665   safe         384127       DIVASON MATEYU          2024-07-18       882504.0         299564.0   Gen_Surg
# 1666   safe         384127       DIVASON MATEYU          2024-07-18       882504.0         299564.0   Gen_Surg
# 1706   safe         389772      GRESHAN CHILASA          2024-09-11       817717.0          96797.0   Gen_Surg
# 1707   safe         389772      GRESHAN CHILASA          2024-09-11       817717.0          96797.0   Gen_Surg
# 1294  mercy         389772      GRESHAN CHILASA          2024-10-07       128200.0          98200.0   Gen_Surg
# 1295  mercy         389772      GRESHAN CHILASA          2024-10-07       128200.0          98200.0   Gen_Surg
# 1360  mercy         393498       VELINA KASHONI          2024-10-25       300650.0         200650.0   Gen_Surg
# 1361  mercy         393498       VELINA KASHONI          2024-10-25       300650.0         200650.0   Gen_Surg
# 1737   safe         393498        VELINA KASHON          2024-11-13       833476.0        -612154.0   Gen_Surg
# 1738   safe         393498        VELINA KASHON          2024-11-13       833476.0        -612154.0   Gen_Surg
#
# === OLASIO entries — likely same person? ===
#        fund        fund_name patient_number fund_admission_date  theatre_index    theatre_name tb_diagnosis
# 1052  mercy   OLASIO ANTONIO         376856          2024-05-13       240616.0  OLASIO ANTONIO   Other_Surg
# 1053  mercy   OLASIO ANTONIO         376856          2024-05-13       240651.0  OLASIO ANTONIO   Other_Surg
# 1054  mercy   OLASIO ANTONIO         376856          2024-05-13       240732.0  OLASIO ANTONIO   Other_Surg
# 1055  mercy   OLASIO ANTONIO         376856          2024-05-13       240860.0  OLASIO ANTONIO   Other_Surg
# 1458  mercy  OLASIO ANTHONYO            NaN          2024-04-05       240534.0  OLISIO ANTONIO  Other_Ortho
# 1459  mercy  OLASIO ANTHONYO            NaN          2024-04-05       240544.0  OLISIO ANTONIO   Other_Surg
# 1460  mercy  OLASIO ANTHONYO            NaN          2024-04-05       240616.0  OLASIO ANTONIO   Other_Surg
# 1461  mercy  OLASIO ANTHONYO            NaN          2024-04-05       240651.0  OLASIO ANTONIO   Other_Surg
#
# === SAFE: safe_fund_mk distribution ===
# Positive (SAFE covered more than billed): 143
# Negative (SAFE fixed price < actual bill): 154
# Null: 264
#
# Median safe_ask_usd: $476
# Median total_bill_mk: 833,476 MK

# %%
final
# Out:
#        fund match_status match_type  fuzzy_score  unmatched_reason  \
# 0     mercy    unmatched  unmatched          NaN  outside_TB_range
# 1     mercy    unmatched  unmatched          NaN  outside_TB_range
# 2     mercy    unmatched  unmatched          NaN  outside_TB_range
# 3     mercy    unmatched  unmatched          NaN  outside_TB_range
# 4     mercy    unmatched  unmatched          NaN  outside_TB_range
# ...     ...          ...        ...          ...               ...
# 2052   safe    unmatched  unmatched          NaN              None
# 2053   safe    unmatched  unmatched          NaN              None
# 2054   safe    unmatched  unmatched          NaN              None
# 2055   safe    unmatched  unmatched          NaN              None
# 2056   safe    unmatched  unmatched          NaN              None
#
#      cross_fund_flag            fund_name patient_number  age  gender  ...  \
# 0              False       MOSES MANGUISA             66  NaN    Male  ...
# 1              False     KACHIGAMBA MWALE            276  NaN    Male  ...
# 2              False      EFRINA CHIKONDI            362  NaN  Female  ...
# 3              False        PAMELA MWELWA            706  NaN  Female  ...
# 4              False         ERIC MALINGA            922  NaN    Male  ...
# ...              ...                  ...            ...  ...     ...  ...
# 2052           False  2023-11-01 00:00:00            NaN  NaN     NaN  ...
# 2053           False  2023-12-01 00:00:00            NaN  NaN     NaN  ...
# 2054           False                WATSI            NaN  NaN     NaN  ...
# 2055           False                 NAME            NaN  NaN  Gender  ...
# 2056           False          CONTINGENCY            NaN  NaN     NaN  ...
#
#      procedure_free_text tb_surgery_type indication_for_surgery  urgency  \
# 0                    NaN             NaN                    NaN     None
# 1                    NaN             NaN                    NaN     None
# 2                    NaN             NaN                    NaN     None
# 3                    NaN             NaN                    NaN     None
# 4                    NaN             NaN                    NaN     None
# ...                  ...             ...                    ...      ...
# 2052                 NaN             NaN                    NaN     None
# 2053                 NaN             NaN                    NaN     None
# 2054                 NaN             NaN                    NaN     None
# 2055                 NaN             NaN                    NaN     None
# 2056                 NaN             NaN                    NaN     None
#
#       surgery_severity  asascore  days_since_last_mercy  \
# 0                 None       NaN                    NaN
# 1                 None       NaN                    NaN
# 2                 None       NaN                    NaN
# 3                 None       NaN                    NaN
# 4                 None       NaN                    NaN
# ...                ...       ...                    ...
# 2052              None       NaN                    NaN
# 2053              None       NaN                    NaN
# 2054              None       NaN                    NaN
# 2055              None       NaN                    NaN
# 2056              None       NaN                    NaN
#
#       possible_duplicate_mercy  days_since_last_safe  possible_duplicate_safe
# 0                        False                   NaN                      NaN
# 1                        False                   NaN                      NaN
# 2                        False                   NaN                      NaN
# 3                        False                   NaN                      NaN
# 4                        False                   NaN                      NaN
# ...                        ...                   ...                      ...
# 2052                       NaN                   NaN                    False
# 2053                       NaN                   NaN                    False
# 2054                       NaN                   NaN                    False
# 2055                       NaN                   NaN                    False
# 2056                       NaN                   NaN                    False
#
# [2057 rows x 41 columns]
