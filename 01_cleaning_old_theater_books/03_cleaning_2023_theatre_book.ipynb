# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
import sys
from pathlib import Path
import requests
import time
import re
sys.path.append(os.path.abspath(".."))

from helpers.df_formating import (
    convert_to_integer, 
    convert_cols_to_snake_case,
    normalize,
    drop_row_if_not_complete, 
    drop_if_unnamed, 
    excel_time_to_minutes)

from helpers.geo_coding import prepare_village_for_geocoding, geocode_place_mapbox_v5, geocode_unique_queries_mapbox

def to_analyze(df, cols):
    to_analyze = df[cols]
    path_desktop = "/mnt/c/Users/matth/Desktop"
    path_file = f"{path_desktop}/to_analyze.csv"
    to_analyze.to_csv(path_file, index=False)

# %%
# --- read token from ../secrets.txt ---
secrets_path = Path("..") / "secrets.txt"

token = None
with open(secrets_path) as f:
    for line in f:
        if line.startswith("MAP_BOX_TOKEN="):
            token = line.strip().split("=", 1)[1]
            break

assert token is not None, "MAP_BOX_TOKEN not found in secrets.txt"

MAPBOX_TOKEN = token

# %%
base_dir ="../Nkhoma_data/Data"

# %%
# all the files
os.listdir(base_dir)
# Out:
# ['2022_theatre_books_clean_unknown_villages.xlsx',
#  'old_theatre_books_clean.xlsx',
#  'Theatre_Book-Database 2025-plain.xlsx',
#  'old_theatre_books_clean.pkl',
#  'Old Theatre Books.xlsx',
#  '2022_theatre_books_clean.xlsx',
#  '.ipynb_checkpoints',
#  'Theatre_Book-Database 2022 Auswertung-Arbeitsversion.xlsx',
#  'Theatre_Book-Database 2024 Auswertung-Arbeitsversion.xlsx',
#  '2022_theatre_books_clean.pkl',
#  'theatre_book_database_2022_clean.pkl',
#  'Theatre_Book-Database 2023 Auswertung-Arbeitsversion.xlsx',
#  '2022_theatre_books_clean_known_villages.pkl',
#  '2022_theatre_books_clean_unknown_villages.pkl',
#  '2022_theatre_books_clean_known_villages.xlsx',
#  'theatre_book_database_2022_clean.xlsx']

# %%
file_to_clean = "Theatre_Book-Database 2023 Auswertung-Arbeitsversion.xlsx"
path = f"{base_dir}/{file_to_clean}"
df = pd.read_excel(path, engine="openpyxl")
df.head()
# Out:
# /home/mat2m10/.pyenv/versions/3.12.9/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   Theatre Book #  Hospital ID #      DATE of Surgery First Name Last Name  \
# 0         230001            NaN  2023-01-01 00:00:00     SUZEN     WISDON
# 1         230002            NaN  2023-01-02 00:00:00     BEZAI     MANUEL
# 2         230003            NaN  2023-01-02 00:00:00    ELLINA     LUPIYA
# 3         230004            NaN  2023-01-02 00:00:00       HAWA    SAMSON
# 4         230005            NaN  2023-01-03 00:00:00     JUDITH   BONFACE
#
#    Age (years) Sex   Village  Surgeon 1st Assistent/Instructor   ...  \
# 0         26.0   F   MITAMBO  Obs/Gyn                       NaN  ...
# 1         37.0   M  MAZENGER    Terry                      Vitu  ...
# 2         30.0   F   CHIDUMA  Obs/Gyn                     Other  ...
# 3         28.0   F   TAMBALA  Obs/Gyn                     Other  ...
# 4         22.0   F   TAMBALA  Obs/Gyn                     Other  ...
#
#      Urgency Surgery severity ASA-Score Year of birth  \
# 0  Emergency            Major       NaN        1997.0
# 1     Urgent            Major       NaN        1986.0
# 2   Elective            Major       NaN        1993.0
# 3  Emergency     Intermediate       NaN        1995.0
# 4  Emergency     Intermediate       NaN        2001.0
#
#   Operation time (minutes) Unnamed: 30                  Unnamed: 31  \
# 0                 00:45:00         NaN  Calculated: do not fill out
# 1      1899-12-29 13:15:00         NaN                          NaN
# 2      1899-12-29 22:55:00         NaN                          NaN
# 3      1899-12-29 18:30:00         NaN                          NaN
# 4                 00:43:00         NaN                          NaN
#
#                   Unnamed: 32                   Unnamed: 33  \
# 0  Fill out for every patient  Fill out for all PAACS cases
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#              Unnamed: 34
# 0  Fill out if possible
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 35 columns]

# %%
df = convert_cols_to_snake_case(df)
df = drop_if_unnamed(df)
# coerce theatre_book to numeric (invalid entries → NaN)
df["theatre_book"] = pd.to_numeric(df["theatre_book"], errors="coerce")
# keep only rows with a valid theatre_book number
df = df.dropna(subset=["theatre_book"])
df = convert_to_integer(df, ['theatre_book', 'hospital_id', 'age_years', 'year_of_birth'])
# rewrite typos
df = df.rename(columns={
    "sarting_time": "starting_time",
    "asascore": "asa_score",
})

# %%
to_analyze(df, ['village'])

# %%
# Drop hospital_id 99% missing
df = df.drop(columns=["hospital_id"])

# %%
# convert date_of_surgery to datetime
df["date_of_surgery"] = pd.to_datetime(
    df["date_of_surgery"],
    errors="coerce"
)

# %%
# Standardize age
df["age_years"].describe()
df["age_years"] = df["age_years"].astype("Int64")
df["age_years"].dtype
df["age_years"].isna().sum()
# Out:
# 139

# %%
# Standardizing sex
df["sex"].value_counts(dropna=False)
df["sex"] = pd.Categorical(
    df["sex"],
    categories=["F", "M"]
)

# %%
df["surgeon"] = (
    df["surgeon"]
    .str.strip()
    .str.title()
)
df["surgeon"].value_counts(dropna=False)
# Out:
# surgeon
# Obs/Gyn      764
# Limbe        281
# Caleb        169
# Lam          162
# Widmann      152
# Terry        105
# NaN           88
# Madalitso     86
# Thoko         73
# Vitu          62
# Vaylann       52
# Other         50
# Stuebing      50
# Wongani       40
# Name: count, dtype: int64

# %%
def classify_surgeon(x):
    if pd.isna(x):
        return "unknown"

    x = str(x).strip()

    if x.lower() == "obs/gyn":
        return "specialty"
    if x.lower() in ["limbe", "lam"]:
        return "facility"
    if x.lower() == "other":
        return "unknown"

    return "individual"
df["surgeon_type"] = df["surgeon"].apply(classify_surgeon)

# %%
df["surgeon_type"] = pd.Categorical(
    df["surgeon_type"],
    categories=["individual", "facility", "specialty", "unknown"]
)

# %%
for col in ["first_name", "last_name"]:
    df[col] = (
        df[col]
        .astype("string")
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
        .str.title()
    )

# %%
df[["first_name", "last_name"]].isna().sum()
# Out:
# first_name    114
# last_name     123
# dtype: int64

# %%
df = prepare_village_for_geocoding(df, col="village")
df["place_type"].value_counts()
df[["village", "village_norm", "place_type", "geocode_query"]].head(20)
# Out:
#      village village_norm place_type geocode_query
# 0    MITAMBO      mitambo    village       mitambo
# 1   MAZENGER     mazenger    village      mazenger
# 2    CHIDUMA      chiduma    village       chiduma
# 3    TAMBALA      tambala    village       tambala
# 4    TAMBALA      tambala    village       tambala
# 5   CHIPHWAN     chiphwan    village      chiphwan
# 6    MSUMATI      msumati    village       msumati
# 7    NGONGOL      ngongol    village       ngongol
# 8      NKONO        nkono    village         nkono
# 9    NKOPOKA      nkopoka    village       nkopoka
# 10   KAPHUKA      kaphuka    village       kaphuka
# 11  MAZENGER     mazenger    village      mazenger
# 12   TAMBALA      tambala    village       tambala
# 13  CHILUNDA     chilunda    village      chilunda
# 14     VILLA        villa    village         villa
# 15    KAGOKA       kagoka    village        kagoka
# 16     CHIGO        chigo    village         chigo
# 17      YONA         yona    village          yona
# 18  NJOVUYAL     njovuyal    village      njovuyal
# 19   KAMONDI      kamondi    village       kamondi

# %%
df2, geo_df = geocode_unique_queries_mapbox(df, token)
# quick sanity checks
geo_df.sort_values(["error", "relevance"], ascending=[True, False]).head(20)
df2[["village", "place_type", "geocode_query", "lat", "lon", "place_name", "relevance", "error"]].head(30)
# Out:
#        village place_type geocode_query        lat        lon  \
# 0      MITAMBO    village       mitambo -12.650819  34.175367
# 1     MAZENGER    village      mazenger -13.215804  33.739164
# 2      CHIDUMA    village       chiduma -13.215804  33.739164
# 3      TAMBALA    village       tambala -12.873253  33.629595
# 4      TAMBALA    village       tambala -12.873253  33.629595
# 5     CHIPHWAN    village      chiphwan -13.215804  33.739164
# 6      MSUMATI    village       msumati -13.215804  33.739164
# 7      NGONGOL    village       ngongol -13.215804  33.739164
# 8        NKONO    village         nkono -13.215804  33.739164
# 9      NKOPOKA    village       nkopoka -14.307734  35.117773
# 10     KAPHUKA    village       kaphuka -14.148509  34.181856
# 11    MAZENGER    village      mazenger -13.215804  33.739164
# 12     TAMBALA    village       tambala -12.873253  33.629595
# 13    CHILUNDA    village      chilunda -15.300392  34.701808
# 14       VILLA    village         villa -13.215804  33.739164
# 15      KAGOKA    village        kagoka -15.348073  34.530837
# 16       CHIGO    village         chigo -13.215804  33.739164
# 17        YONA    village          yona -13.215804  33.739164
# 18    NJOVUYAL    village      njovuyal -13.215804  33.739164
# 19     KAMONDI    village       kamondi -13.215804  33.739164
# 20      MLANDA    village        mlanda -14.478535  34.447182
# 21     KAFWAFW    village       kafwafw -13.215804  33.739164
# 22     Kangome    village       kangome -15.351656  34.811255
# 23    Chinsapo    village      chinsapo -13.215804  33.739164
# 24     Mkwanda    village       mkwanda -12.989511  34.286530
# 25    Kanyumbu    village      kanyumbu -15.300392  34.701808
# 26      Mijala    village        mijala -13.215804  33.739164
# 27   Mazengera    village     mazengera -15.300392  34.701808
# 28  Mankhukula    village    mankhukula -13.215804  33.739164
# 29      Mpando    village        mpando -14.046481  33.378233
#
#                      place_name  relevance error
# 0    Mtambo, Nkhotakota, Malawi   0.964286  None
# 1                        Malawi   0.500000  None
# 2                        Malawi   0.500000  None
# 3      Tambala, Kasungu, Malawi   1.000000  None
# 4      Tambala, Kasungu, Malawi   1.000000  None
# 5                        Malawi   0.500000  None
# 6                        Malawi   0.500000  None
# 7                        Malawi   0.500000  None
# 8                        Malawi   0.500000  None
# 9     Nkopola, Mangochi, Malawi   0.964286  None
# 10       Kaphuka, Dedza, Malawi   1.000000  None
# 11                       Malawi   0.500000  None
# 12     Tambala, Kasungu, Malawi   1.000000  None
# 13         Malawi, Neno, Malawi   0.500000  None
# 14                       Malawi   0.500000  None
# 15         Kagona, Neno, Malawi   0.958333  None
# 16                       Malawi   0.500000  None
# 17                       Malawi   0.500000  None
# 18                       Malawi   0.500000  None
# 19                       Malawi   0.500000  None
# 20       Mlanda, Ntcheu, Malawi   1.000000  None
# 21                       Malawi   0.500000  None
# 22       Kangombe, Neno, Malawi   0.964286  None
# 23                       Malawi   0.500000  None
# 24  Mkwanda, Nkhotakota, Malawi   1.000000  None
# 25         Malawi, Neno, Malawi   0.500000  None
# 26                       Malawi   0.500000  None
# 27         Malawi, Neno, Malawi   0.500000  None
# 28                       Malawi   0.500000  None
# 29    Mphando, Lilongwe, Malawi   0.958333  None

# %%
df2["village_norm_cmp"] = df2["village"].apply(normalize)
df2["place_first"] = df2["place_name"].str.split(",").str[0]
df2["place_first_norm_cmp"] = df2["place_first"].apply(normalize)

df_matched = df2[df2["village_norm_cmp"] == df2["place_first_norm_cmp"]]
df_diff = df2[df2["village_norm_cmp"] != df2["place_first_norm_cmp"]]

pkl_path = f"{base_dir}/2023_theatre_books_clean.pkl"
xlsx_path = f"{base_dir}/2023_theatre_books_clean.xlsx"
df2.to_pickle(pkl_path)
df2.to_excel(xlsx_path, index=False)
pkl_path = f"{base_dir}/2023_theatre_books_clean_known_villages.pkl"
xlsx_path = f"{base_dir}/2023_theatre_books_clean_known_villages.xlsx"
df_matched.to_pickle(pkl_path)
df_matched.to_excel(xlsx_path, index=False)
pkl_path = f"{base_dir}/2023_theatre_books_clean_unknown_villages.pkl"
xlsx_path = f"{base_dir}/2023_theatre_books_clean_unknown_villages.xlsx"
df_diff.to_pickle(pkl_path)
df_diff.to_excel(xlsx_path, index=False)

# %%
df_matched
# Out:
#       theatre_book date_of_surgery first_name  last_name  age_years sex  \
# 3           230004      2023-01-02       Hawa     Samson         28   F
# 4           230005      2023-01-03     Judith    Bonface         22   F
# 10          230011      2023-01-06     Thomas    Richard         42   M
# 12          230013      2023-01-06      Saidi      Sanji         40   M
# 20          230021      2023-01-08      Suzen      Rogie         19   F
# ...            ...             ...        ...        ...        ...  ..
# 2121        232122      2023-12-25     Lemita    Ephraim         32   F
# 2124        232125      2023-12-28      Olipa     Alfred         29   F
# 2125        232126      2023-12-28     Estere      Asidi         33   F
# 2130        232131      2023-12-31     Stella  Chimwenje         28   F
# 2132        232133      2023-12-31    Esinati   Lusitiko         19   F
#
#       village  surgeon first_assistent_instructor second_assistent  ...  \
# 3     TAMBALA  Obs/Gyn                      Other            Other  ...
# 4     TAMBALA  Obs/Gyn                      Other            Other  ...
# 10    KAPHUKA     Vitu                      Limbe              NaN  ...
# 12    TAMBALA     Vitu                        Lam              NaN  ...
# 20     MLANDA  Obs/Gyn                      Other            Other  ...
# ...       ...      ...                        ...              ...  ...
# 2121    DEDZA  Obs/Gyn                    Obs/Gyn              NaN  ...
# 2124  MPHANDE  Obs/Gyn                    Obs/Gyn              NaN  ...
# 2125  MAPEMBA  Obs/Gyn                    Obs/Gyn              NaN  ...
# 2130  KACHERE  Obs/Gyn                    Obs/Gyn              NaN  ...
# 2132  KALONGA  Obs/Gyn                    Obs/Gyn              NaN  ...
#
#      geocode_query        lon        lat                place_name relevance  \
# 3          tambala  33.629595 -12.873253  Tambala, Kasungu, Malawi       1.0
# 4          tambala  33.629595 -12.873253  Tambala, Kasungu, Malawi       1.0
# 10         kaphuka  34.181856 -14.148509    Kaphuka, Dedza, Malawi       1.0
# 12         tambala  33.629595 -12.873253  Tambala, Kasungu, Malawi       1.0
# 20          mlanda  34.447182 -14.478535    Mlanda, Ntcheu, Malawi       1.0
# ...            ...        ...        ...                       ...       ...
# 2121         dedza  34.328238 -14.380727             Dedza, Malawi       1.0
# 2124       mphande  35.201466 -16.339190   Mphande, Thyolo, Malawi       1.0
# 2125       mapemba  34.222142 -14.097290    Mapemba, Dedza, Malawi       1.0
# 2130       kachere  34.682674 -15.372861     Kachere, Neno, Malawi       1.0
# 2132       kalonga  34.583758 -14.901570   Kalonga, Ntcheu, Malawi       1.0
#
#           feature_id error place_first village_norm_cmp place_first_norm_cmp
# 3     place.10791070  None     Tambala          tambala              tambala
# 4     place.10791070  None     Tambala          tambala              tambala
# 10     place.4499614  None     Kaphuka          kaphuka              kaphuka
# 12    place.10791070  None     Tambala          tambala              tambala
# 20     place.7497886  None      Mlanda           mlanda               mlanda
# ...              ...   ...         ...              ...                  ...
# 2121   region.132254  None       Dedza            dedza                dedza
# 2124   place.7817374  None     Mphande          mphande              mphande
# 2125   place.6547614  None     Mapemba          mapemba              mapemba
# 2130   place.3582110  None     Kachere          kachere              kachere
# 2132   place.3926174  None     Kalonga          kalonga              kalonga
#
# [681 rows x 42 columns]
