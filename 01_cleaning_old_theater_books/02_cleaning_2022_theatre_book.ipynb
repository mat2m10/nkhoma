# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
import sys
from pathlib import Path
import requests
import time
import re
sys.path.append(os.path.abspath(".."))

from helpers.df_formating import (
    convert_to_integer, 
    convert_cols_to_snake_case,
    normalize,
    drop_row_if_not_complete, 
    drop_if_unnamed, 
    excel_time_to_minutes)

from helpers.geo_coding import prepare_village_for_geocoding, geocode_place_mapbox_v5, geocode_unique_queries_mapbox

def to_analyze(df, cols):
    to_analyze = df[cols]
    path_desktop = "/mnt/c/Users/matth/Desktop"
    path_file = f"{path_desktop}/to_analyze.csv"
    to_analyze.to_csv(path_file, index=False)

# %%
# --- read token from ../secrets.txt ---
secrets_path = Path("..") / "secrets.txt"

token = None
with open(secrets_path) as f:
    for line in f:
        if line.startswith("MAP_BOX_TOKEN="):
            token = line.strip().split("=", 1)[1]
            break

assert token is not None, "MAP_BOX_TOKEN not found in secrets.txt"

MAPBOX_TOKEN = token

# %%
base_dir ="../Nkhoma_data/Data"

# %%
# all the files
os.listdir(base_dir)
# Out:
# ['old_theatre_books_clean.xlsx',
#  'Theatre_Book-Database 2025-plain.xlsx',
#  'old_theatre_books_clean.pkl',
#  'Old Theatre Books.xlsx',
#  '.ipynb_checkpoints',
#  'Theatre_Book-Database 2022 Auswertung-Arbeitsversion.xlsx',
#  'Theatre_Book-Database 2024 Auswertung-Arbeitsversion.xlsx',
#  'theatre_book_database_2022_clean.pkl',
#  'Theatre_Book-Database 2023 Auswertung-Arbeitsversion.xlsx',
#  'theatre_book_database_2022_clean.xlsx']

# %% [markdown]
# # Lets clean Theatre_Book-Database 2022 Auswertung-Arbeitsversion.xlsx

# %%
file_to_clean = "Theatre_Book-Database 2022 Auswertung-Arbeitsversion.xlsx"
path = f"{base_dir}/{file_to_clean}"
df = pd.read_excel(path, engine="openpyxl")
df.head()
# Out:
# /home/mat2m10/.pyenv/versions/3.12.9/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   Theatre Book #  Hospital ID # DATE of Surgery First Name   Last Name  \
# 0         220001            NaN      2022-01-01      Elifa      Sumati
# 1         220002            NaN      2022-01-01     Siyatu       Isaac
# 2         220003            NaN      2022-01-02     Loness  Mapemphero
# 3         220004            NaN      2022-01-03      Saizi      Nedson
# 4         220005            NaN      2022-01-03   Beatrice     Hezekia
#
#    Age (years) Sex       Village  Surgeon 1st Assistent/Instructor   ...  \
# 0         26.0   F       Nkhonde  Obs/Gyn                       NaN  ...
# 1         27.0   F    Mozambique  Obs/Gyn                       NaN  ...
# 2         25.0   F        Chembe  Obs/Gyn                       NaN  ...
# 3         48.0   M  Chilikumanda    Limbe                     Caleb  ...
# 4         26.0   F     Mazengera  Obs/Gyn                       NaN  ...
#
#      Urgency Surgery severity ASA-Score Year of birth  \
# 0        NaN              NaN       NaN        1997.0
# 1        NaN              NaN       NaN        1996.0
# 2        NaN              NaN       NaN        1998.0
# 3  Emergency            Major     ASA 3        1975.0
# 4        NaN              NaN       NaN        1997.0
#
#   Operation time (minutes) Unnamed: 30                  Unnamed: 31  \
# 0                 00:00:00         NaN  Calculated: do not fill out
# 1                 00:00:00         NaN                          NaN
# 2                 00:00:00         NaN                          NaN
# 3                 00:00:00         NaN                          NaN
# 4                 00:00:00         NaN                          NaN
#
#                   Unnamed: 32                   Unnamed: 33  \
# 0  Fill out for every patient  Fill out for all PAACS cases
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#              Unnamed: 34
# 0  Fill out if possible
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 35 columns]

# %%
df = convert_cols_to_snake_case(df)
df = drop_if_unnamed(df)
# coerce theatre_book to numeric (invalid entries → NaN)
df["theatre_book"] = pd.to_numeric(df["theatre_book"], errors="coerce")
# keep only rows with a valid theatre_book number
df = df.dropna(subset=["theatre_book"])
df = convert_to_integer(df, ['theatre_book', 'hospital_id', 'age_years', 'year_of_birth'])
# rewrite typos
df = df.rename(columns={
    "sarting_time": "starting_time",
    "asascore": "asa_score",
})

# %%
df.columns
# Out:
# Index(['theatre_book', 'hospital_id', 'date_of_surgery', 'first_name',
#        'last_name', 'age_years', 'sex', 'village', 'surgeon',
#        'first_assistent_instructor', 'second_assistent', 'anaestesist',
#        'nurse', 'anesthesia', 'department', 'indication_for_surgery',
#        'surgery_type', 'final_diagnosis_category', 'final_diagnosis_free_text',
#        'side', 'main_procedure_category', 'procedure_free_text', 'histology',
#        'starting_time', 'finishing_time', 'urgency', 'surgery_severity',
#        'asa_score', 'year_of_birth', 'operation_time_minutes'],
#       dtype='object')

# %%
to_analyze(df, ['village'])

# %%
# Drop hospital_id 99% missing
df = df.drop(columns=["hospital_id"])

# %%
# convert date_of_surgery to datetime
df["date_of_surgery"] = pd.to_datetime(
    df["date_of_surgery"],
    errors="coerce"
)

# %%
# Standardize age
df["age_years"].describe()
df["age_years"] = df["age_years"].astype("Int64")
df["age_years"].dtype
df["age_years"].isna().sum()
# Out:
# 33

# %%
# Standardizing sex
df["sex"].value_counts(dropna=False)
df["sex"] = pd.Categorical(
    df["sex"],
    categories=["F", "M"]
)

# %%
# Cleaning surgeon
df["surgeon"].value_counts(dropna=False)
# Out:
# surgeon
# Obs/Gyn     755
# Limbe       197
# Lam         154
# Caleb        97
# Terry        79
# Widmann      57
# Stuebing     48
# Other        35
# Vitu         34
# Vaylann      32
# obs/Gyn      21
# Thoko        16
# lam          13
# NaN           2
# Name: count, dtype: int64

# %%
df["surgeon"] = (
    df["surgeon"]
    .str.strip()
    .str.title()
)

# %%
# Classify when not an individual
def classify_surgeon(x):
    if pd.isna(x):
        return "unknown"
    if x == "Obs/Gyn":
        return "specialty"
    if x in ["Limbe", "Lam"]:
        return "facility"
    if x == "Other":
        return "unknown"
    return "individual"

df["surgeon_type"] = df["surgeon"].apply(classify_surgeon)

# %%
df["surgeon_type"] = pd.Categorical(
    df["surgeon_type"],
    categories=["individual", "facility", "specialty", "unknown"]
)

# %%
# normalize names

# %%
for col in ["first_name", "last_name"]:
    df[col] = (
        df[col]
        .astype("string")
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
        .str.title()
    )

# %%
df[["first_name", "last_name"]].isna().sum()
# Out:
# first_name    3
# last_name     4
# dtype: int64

# %%
# Cleaning village

df["village"].value_counts(dropna=False)
# Out:
# village
# Lilongwe      294
# Dedza         162
# Mazengera     129
# NaN           114
# MAZENGERA      48
#              ...
# Ntchisi         1
# Mtemwende       1
# Mponera         1
# Chiradzulu      1
# MCHEDZA         1
# Name: count, Length: 446, dtype: int64

# %%
df = prepare_village_for_geocoding(df, col="village")
df["place_type"].value_counts()
df[["village", "village_norm", "place_type", "geocode_query"]].head(20)
# Out:
#          village  village_norm        place_type geocode_query
# 0        Nkhonde       nkhonde           village       nkhonde
# 1     Mozambique    mozambique   foreign_country          <NA>
# 2         Chembe        chembe           village        chembe
# 3   Chilikumanda  chilikumanda           village  chilikumanda
# 4      Mazengera     mazengera           village     mazengera
# 5      Mazengera     mazengera           village     mazengera
# 6       Kamphika      kamphika           village      kamphika
# 7      Mazengera     mazengera           village     mazengera
# 8          Mzuzu         mzuzu           village         mzuzu
# 9      Mazengera     mazengera           village     mazengera
# 10       Tambala       tambala           village       tambala
# 11          <NA>          <NA>           missing          <NA>
# 12      Lilongwe      lilongwe  district_or_city      lilongwe
# 13       Kaphuka       kaphuka           village       kaphuka
# 14     Mazengera     mazengera           village     mazengera
# 15         Dedza         dedza  district_or_city         dedza
# 16       Tambala       tambala           village       tambala
# 17      Malenges      malenges           village      malenges
# 18      Lilongwe      lilongwe  district_or_city      lilongwe
# 19       Kaphuka       kaphuka           village       kaphuka

# %%
df2, geo_df = geocode_unique_queries_mapbox(df, token)

# quick sanity checks
geo_df.sort_values(["error", "relevance"], ascending=[True, False]).head(20)
df2[["village", "place_type", "geocode_query", "lat", "lon", "place_name", "relevance", "error"]].head(30)
# Out:
#          village        place_type geocode_query        lat        lon  \
# 0        Nkhonde           village       nkhonde -15.300392  34.701808
# 1     Mozambique   foreign_country          <NA>        NaN        NaN
# 2         Chembe           village        chembe -14.021800  34.846135
# 3   Chilikumanda           village  chilikumanda -13.215804  33.739164
# 4      Mazengera           village     mazengera -15.300392  34.701808
# 5      Mazengera           village     mazengera -15.300392  34.701808
# 6       Kamphika           village      kamphika -13.215804  33.739164
# 7      Mazengera           village     mazengera -15.300392  34.701808
# 8          Mzuzu           village         mzuzu -11.460752  34.022642
# 9      Mazengera           village     mazengera -15.300392  34.701808
# 10       Tambala           village       tambala -12.873253  33.629595
# 11          <NA>           missing          <NA>        NaN        NaN
# 12      Lilongwe  district_or_city      lilongwe -13.987511  33.768144
# 13       Kaphuka           village       kaphuka -14.148509  34.181856
# 14     Mazengera           village     mazengera -15.300392  34.701808
# 15         Dedza  district_or_city         dedza -14.380727  34.328238
# 16       Tambala           village       tambala -12.873253  33.629595
# 17      Malenges           village      malenges -15.300392  34.701808
# 18      Lilongwe  district_or_city      lilongwe -13.987511  33.768144
# 19       Kaphuka           village       kaphuka -14.148509  34.181856
# 20       Kaphuka           village       kaphuka -14.148509  34.181856
# 21       Kaphuka           village       kaphuka -14.148509  34.181856
# 22     Mazengera           village     mazengera -15.300392  34.701808
# 23     Chitukula           village     chitukula -13.215804  33.739164
# 24        Tomasi           village        tomasi -15.282705  35.399202
# 25     Khombedza           village     khombedza -13.215804  33.739164
# 26       Kachere           village       kachere -15.372861  34.682674
# 27    Mozambique   foreign_country          <NA>        NaN        NaN
# 28     Mazengera           village     mazengera -15.300392  34.701808
# 29       Kaphuka           village       kaphuka -14.148509  34.181856
#
#                   place_name  relevance error
# 0       Malawi, Neno, Malawi   0.500000  None
# 1                        NaN        NaN   NaN
# 2   Chembe, Mangochi, Malawi   1.000000  None
# 3                     Malawi   1.000000  None
# 4       Malawi, Neno, Malawi   0.500000  None
# 5       Malawi, Neno, Malawi   0.500000  None
# 6                     Malawi   0.500000  None
# 7       Malawi, Neno, Malawi   0.500000  None
# 8              Mzuzu, Malawi   1.000000  None
# 9       Malawi, Neno, Malawi   0.500000  None
# 10  Tambala, Kasungu, Malawi   1.000000  None
# 11                       NaN        NaN   NaN
# 12          Lilongwe, Malawi   1.000000  None
# 13    Kaphuka, Dedza, Malawi   1.000000  None
# 14      Malawi, Neno, Malawi   0.500000  None
# 15             Dedza, Malawi   1.000000  None
# 16  Tambala, Kasungu, Malawi   1.000000  None
# 17      Malawi, Neno, Malawi   0.500000  None
# 18          Lilongwe, Malawi   1.000000  None
# 19    Kaphuka, Dedza, Malawi   1.000000  None
# 20    Kaphuka, Dedza, Malawi   1.000000  None
# 21    Kaphuka, Dedza, Malawi   1.000000  None
# 22      Malawi, Neno, Malawi   0.500000  None
# 23                    Malawi   0.500000  None
# 24     Domasi, Zomba, Malawi   0.958333  None
# 25                    Malawi   0.500000  None
# 26     Kachere, Neno, Malawi   1.000000  None
# 27                       NaN        NaN   NaN
# 28      Malawi, Neno, Malawi   0.500000  None
# 29    Kaphuka, Dedza, Malawi   1.000000  None

# %%
import pandas as pd
import re

def first_token(place_name: str):
    if pd.isna(place_name):
        return pd.NA
    # take text before first comma, trim
    return str(place_name).split(",")[0].strip()

def keep_if_first_word_matches(df):
    df["place_first_token"] = df["place_name"].apply(first_token)
    df["place_first_token_norm"] = df["place_first_token"].apply(normalize)

    # match against your normalized village query
    df["first_token_matches"] = (
        df["place_first_token_norm"].notna()
        & df["geocode_query"].notna()
        & (df["place_first_token_norm"] == df["geocode_query"])
    )

    # final rule: keep coords only if match (and not missing)
    df["keep_geocode"] = df["first_token_matches"] & df["lat"].notna() & df["lon"].notna()

    return df

# %%
df4 = keep_if_first_word_matches(df2)

df4["keep_geocode"].value_counts()
df4.loc[~df4["keep_geocode"],
        ["village", "geocode_query", "place_name", "place_first_token", "relevance", "lat", "lon"]].head(30)
# Out:
#          village geocode_query                    place_name  \
# 0        Nkhonde       nkhonde          Malawi, Neno, Malawi
# 1     Mozambique          <NA>                           NaN
# 3   Chilikumanda  chilikumanda                        Malawi
# 4      Mazengera     mazengera          Malawi, Neno, Malawi
# 5      Mazengera     mazengera          Malawi, Neno, Malawi
# 6       Kamphika      kamphika                        Malawi
# 7      Mazengera     mazengera          Malawi, Neno, Malawi
# 9      Mazengera     mazengera          Malawi, Neno, Malawi
# 11          <NA>          <NA>                           NaN
# 14     Mazengera     mazengera          Malawi, Neno, Malawi
# 17      Malenges      malenges          Malawi, Neno, Malawi
# 22     Mazengera     mazengera          Malawi, Neno, Malawi
# 23     Chitukula     chitukula                        Malawi
# 24        Tomasi        tomasi         Domasi, Zomba, Malawi
# 25     Khombedza     khombedza                        Malawi
# 27    Mozambique          <NA>                           NaN
# 28     Mazengera     mazengera          Malawi, Neno, Malawi
# 31     Mazengera     mazengera          Malawi, Neno, Malawi
# 32     Mazengera     mazengera          Malawi, Neno, Malawi
# 34        Chedza        chedza      Chadza, Lilongwe, Malawi
# 35    Mozambique          <NA>                           NaN
# 36          <NA>          <NA>                           NaN
# 37     Tsanbango     tsanbango                        Malawi
# 38       Masanga       masanga                        Malawi
# 40    Chitekwere    chitekwere  Chitekwele, Lilongwe, Malawi
# 41     Mazengera     mazengera          Malawi, Neno, Malawi
# 44     Mazengera     mazengera          Malawi, Neno, Malawi
# 45          Wezi          wezi                        Malawi
# 48     Mazengera     mazengera          Malawi, Neno, Malawi
# 50      Chipseye      chipseye                        Malawi
#
#    place_first_token  relevance        lat        lon
# 0             Malawi   0.500000 -15.300392  34.701808
# 1               <NA>        NaN        NaN        NaN
# 3             Malawi   1.000000 -13.215804  33.739164
# 4             Malawi   0.500000 -15.300392  34.701808
# 5             Malawi   0.500000 -15.300392  34.701808
# 6             Malawi   0.500000 -13.215804  33.739164
# 7             Malawi   0.500000 -15.300392  34.701808
# 9             Malawi   0.500000 -15.300392  34.701808
# 11              <NA>        NaN        NaN        NaN
# 14            Malawi   0.500000 -15.300392  34.701808
# 17            Malawi   0.500000 -15.300392  34.701808
# 22            Malawi   0.500000 -15.300392  34.701808
# 23            Malawi   0.500000 -13.215804  33.739164
# 24            Domasi   0.958333 -15.282705  35.399202
# 25            Malawi   0.500000 -13.215804  33.739164
# 27              <NA>        NaN        NaN        NaN
# 28            Malawi   0.500000 -15.300392  34.701808
# 31            Malawi   0.500000 -15.300392  34.701808
# 32            Malawi   0.500000 -15.300392  34.701808
# 34            Chadza   0.958333 -13.969878  33.535424
# 35              <NA>        NaN        NaN        NaN
# 36              <NA>        NaN        NaN        NaN
# 37            Malawi   0.500000 -13.215804  33.739164
# 38            Malawi   0.500000 -13.215804  33.739164
# 40        Chitekwele   0.975000 -13.956537  34.115970
# 41            Malawi   0.500000 -15.300392  34.701808
# 44            Malawi   0.500000 -15.300392  34.701808
# 45            Malawi   0.500000 -13.215804  33.739164
# 48            Malawi   0.500000 -15.300392  34.701808
# 50            Malawi   1.000000 -13.215804  33.739164

# %%
df["village_norm"] = df["village"].apply(normalize)

def classify_place(s):
    if pd.isna(s):
        return "missing"

    # Lilongwe Areas (Area 11, area23, a23)
    if re.match(r"^(area\s*\d+|a\s*\d+)$", s):
        return "lilongwe_area"

    # Mile-based informal locations (6 miles, 6miles)
    if re.match(r"^\d+\s*miles?$", s) or re.match(r"^\d+miles?$", s):
        return "distance_marker"

    # Known landmarks
    if s in {"airfield", "airport", "battalion", "batalion"}:
        return "landmark"

    # Countries / outside Malawi (very important to catch)
    if s in {"mozambique", "zambia", "tanzania"}:
        return "foreign_country"

    # Very short / code-like tokens
    if re.match(r"^[a-z]\d+$", s):
        return "code_like"

    # Everything else: assume village / town name
    return "named_place"

df["place_type"] = df["village_norm"].apply(classify_place)

df["place_type"].value_counts()
# Out:
# place_type
# named_place        1384
# missing             114
# foreign_country      21
# lilongwe_area        16
# landmark              4
# distance_marker       1
# Name: count, dtype: int64

# %%
def build_geocode_query(row, default_city="Lilongwe"):
    s = row["village_norm"]
    t = row["place_type"]

    if t == "missing":
        return pd.Series([pd.NA, "none", 0.0])

    if t == "foreign_country":
        # keep but flag as very low confidence
        return pd.Series([f"{s}", "foreign", 0.2])

    if t == "lilongwe_area":
        # Area-based Lilongwe neighborhoods
        return pd.Series([f"{s.replace('a', 'Area ')}, {default_city}, Malawi", "lilongwe", 0.9])

    if t == "distance_marker":
        # e.g. "6 miles" → peri-urban Lilongwe
        return pd.Series([f"{s}, {default_city}, Malawi", "lilongwe_periurban", 0.7])

    if t == "landmark":
        # anchor landmark searches strongly
        return pd.Series([f"{s}, {default_city}, Malawi", "lilongwe_landmark", 0.8])

    if t == "named_place":
        # normal villages / towns
        return pd.Series([f"{s}, Malawi", "national", 0.85])

    # fallback
    return pd.Series([f"{s}, Malawi", "unknown", 0.4])


df[["geocode_text", "geo_prior", "confidence_prior"]] = (
    df.apply(build_geocode_query, axis=1)
)

df[["village", "place_type", "geocode_text", "geo_prior", "confidence_prior"]].head(20)
# Out:
#          village       place_type          geocode_text geo_prior  \
# 0        nkhonde      named_place       nkhonde, Malawi  national
# 1     mozambique  foreign_country            mozambique   foreign
# 2         chembe      named_place        chembe, Malawi  national
# 3   chilikumanda      named_place  chilikumanda, Malawi  national
# 4      mazengera      named_place     mazengera, Malawi  national
# 5      mazengera      named_place     mazengera, Malawi  national
# 6       kamphika      named_place      kamphika, Malawi  national
# 7      mazengera      named_place     mazengera, Malawi  national
# 8          mzuzu      named_place         mzuzu, Malawi  national
# 9      mazengera      named_place     mazengera, Malawi  national
# 10       tambala      named_place       tambala, Malawi  national
# 11           NaN          missing                  <NA>      none
# 12      lilongwe      named_place      lilongwe, Malawi  national
# 13       kaphuka      named_place       kaphuka, Malawi  national
# 14     mazengera      named_place     mazengera, Malawi  national
# 15         dedza      named_place         dedza, Malawi  national
# 16       tambala      named_place       tambala, Malawi  national
# 17      malenges      named_place      malenges, Malawi  national
# 18      lilongwe      named_place      lilongwe, Malawi  national
# 19       kaphuka      named_place       kaphuka, Malawi  national
#
#     confidence_prior
# 0               0.85
# 1               0.20
# 2               0.85
# 3               0.85
# 4               0.85
# 5               0.85
# 6               0.85
# 7               0.85
# 8               0.85
# 9               0.85
# 10              0.85
# 11              0.00
# 12              0.85
# 13              0.85
# 14              0.85
# 15              0.85
# 16              0.85
# 17              0.85
# 18              0.85
# 19              0.85

# %%
import requests
import time
from pathlib import Path

# Reuse MAPBOX_TOKEN from earlier
PROXIMITY_LILONGWE = (33.78, -13.97)  # lon, lat

def mapbox_geocode(text, proximity=PROXIMITY_LILONGWE, limit=1):
    if pd.isna(text):
        return None

    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{requests.utils.quote(text)}.json"
    params = {
        "access_token": MAPBOX_TOKEN,
        "country": "MW",
        "proximity": f"{proximity[0]},{proximity[1]}",
        "limit": limit,
    }
    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()
    feats = data.get("features", [])
    if not feats:
        return None

    f = feats[0]
    lon, lat = f["center"]
    return {
        "geocode_text": text,
        "lon": lon,
        "lat": lat,
        "place_name": f.get("place_name"),
        "relevance": f.get("relevance", 0.0),
        "feature_id": f.get("id"),
    }


# ---- build unique geocoding table ----
unique_geo = (
    df[["geocode_text"]]
    .dropna()
    .drop_duplicates()
)

cache_path = Path("mapbox_geocoded_results.csv")
if cache_path.exists():
    cache = pd.read_csv(cache_path)
else:
    cache = pd.DataFrame(columns=[
        "geocode_text", "lon", "lat", "place_name", "relevance", "feature_id"
    ])

cached = set(cache["geocode_text"].astype(str))

new_results = []

for text in unique_geo["geocode_text"]:
    if text in cached:
        continue

    result = mapbox_geocode(text)
    new_results.append(
        result if result is not None else {
            "geocode_text": text,
            "lon": pd.NA,
            "lat": pd.NA,
            "place_name": pd.NA,
            "relevance": 0.0,
            "feature_id": pd.NA,
        }
    )
    time.sleep(0.1)

if new_results:
    cache = pd.concat([cache, pd.DataFrame(new_results)], ignore_index=True)
    cache.to_csv(cache_path, index=False)

cache.head(), cache["lat"].notna().mean()
# Out:
# /tmp/ipykernel_9626/314934557.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cache = pd.concat([cache, pd.DataFrame(new_results)], ignore_index=True)
# (           geocode_text        lon        lat                place_name  \
#  0       nkhonde, Malawi  34.701808 -15.300392      Malawi, Neno, Malawi
#  1            mozambique       <NA>       <NA>                      <NA>
#  2        chembe, Malawi  34.846135   -14.0218  Chembe, Mangochi, Malawi
#  3  chilikumanda, Malawi  33.739164 -13.215804                    Malawi
#  4     mazengera, Malawi  34.701808 -15.300392      Malawi, Neno, Malawi
#
#     relevance     feature_id
#  0        0.5  place.6260894
#  1        0.0           <NA>
#  2        1.0   place.870558
#  3        1.0   country.8862
#  4        0.5  place.6260894  ,
#  0.9951573849878934)

# %%
# --- find the right column names if pandas added suffixes ---
def pick_col(base):
    if base in df.columns:
        return base
    for c in df.columns:
        if c.startswith(base + "_"):
            return c
    return None

feature_id_col = pick_col("feature_id")
place_name_col = pick_col("place_name")
relevance_col  = pick_col("relevance")
lat_col        = pick_col("lat")
lon_col        = pick_col("lon")

print("Using columns:", {
    "feature_id": feature_id_col,
    "place_name": place_name_col,
    "relevance": relevance_col,
    "lat": lat_col,
    "lon": lon_col
})

# --- country-level detection ---
if feature_id_col is not None:
    bad_country = df[feature_id_col].astype("string").str.startswith("country.", na=False)
else:
    # fallback: place_name equals "Malawi" or ends with ", Malawi" but is too generic
    bad_country = df[place_name_col].astype("string").str.fullmatch(r"malawi", case=False, na=False)

# --- loose Malawi bounds sanity check ---
out_of_malawi = (
    df[lon_col].notna() & df[lat_col].notna() &
    ((df[lon_col] < 32.6) | (df[lon_col] > 35.9) | (df[lat_col] < -17.2) | (df[lat_col] > -9.3))
)

min_relevance = 0.8
rel = df[relevance_col].fillna(0.0) if relevance_col is not None else 0.0

df["is_bad_geocode"] = (
    df[lat_col].isna() |
    df[lon_col].isna() |
    bad_country |
    (rel < min_relevance) |
    out_of_malawi
)

audit = (
    df.loc[df["is_bad_geocode"], ["village", "geocode_text", place_name_col, relevance_col]]
      .value_counts()
      .head(30)
)

df["is_bad_geocode"].mean(), audit
# Out:
# Using columns: {'feature_id': None, 'place_name': None, 'relevance': None, 'lat': None, 'lon': None}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 31
#      28     bad_country = df[feature_id_col].astype("string").str.startswith("country.", na=False)
#      29 else:
#      30     # fallback: place_name equals "Malawi" or ends with ", Malawi" but is too generic
# ---> 31     bad_country = df[place_name_col].astype("string").str.fullmatch(r"malawi", case=False, na=False)
#      33 # --- loose Malawi bounds sanity check ---
#      34 out_of_malawi = (
#      35     df[lon_col].notna() & df[lat_col].notna() &
#      36     ((df[lon_col] < 32.6) | (df[lon_col] > 35.9) | (df[lat_col] < -17.2) | (df[lat_col] > -9.3))
#      37 )
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: None

# %%
pkl_path = f"{base_dir}/theatre_book_database_2022_clean.pkl"
xlsx_path = f"{base_dir}/theatre_book_database_2022_clean.xlsx"

df.to_pickle(pkl_path)
df.to_excel(xlsx_path, index=False)

# %%
to_analyze(df, ['theatre_book', 'hospital_id', 'date_of_surgery'])
